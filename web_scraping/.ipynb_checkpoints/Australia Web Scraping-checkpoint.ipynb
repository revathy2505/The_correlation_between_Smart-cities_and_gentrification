# %%
from bs4 import BeautifulSoup
import urllib.request as urlib
import pandas as pd
import numpy as np

# %% [markdown]
# # Sydney

# %%
# define all postal codes 
input_file = pd.read_csv('sydney_postalcodes.csv', header=None)
postalcode = input_file.as_matrix()
print(postalcode.shape)
# define years 
years = ["2006", "2011", "2016"]
database = []
# Out:
# (198, 1)

# %%
i = 0
for year in years: 
    print("Year:" , year)
    database.append([])
    i+=1
    for pc in postalcode: 
        pc = pc[0]
        site = "http://www.censusdata.abs.gov.au/census_services/getproduct/census/"+year+"/quickstat/POA"+str(pc)
        page = urlib.urlopen(site)
        soup = BeautifulSoup(page)
        if(year != "2016"):
            table = soup.find_all('table', class_='summaryTable')
            for table in table: 
                tr = table.find_all('tr')
                for row in tr:
                    cells = row.find_all('td')
                    if("Median incomes" in str(cells[0])):
                        c = cells[1].string
                        c = c[1:]
                        c = c.replace(',', '')
                        nr = int(c)
                        database[i-1].append(nr)
                        print("    PC ", pc)
        else: 
            cells = []
            table = soup.find_all('table', class_='summaryTable')
            for table in table: 
                tr = table.find_all('tr')
                for row in tr:
                    cell = row.find_all('td')
                    cells.append(cell[0])
            if(len(cells) != 1):
                c = cells[10].string
                c = c[1:]
                c = c.replace(',', '')
                nr = int(c)
                database[i-1].append(nr)
                print("pc", pc)
            else:
                print("pc: ", pc, "Error")
# Out:
# Year: 2006
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#     PC  2107
#     PC  2106
#     PC  2103
#     PC  2104
#     PC  2102
#     PC  2105
#     PC  2101
#     PC  2084
#     PC  2097
#     PC  2074
#     PC  2075
#     PC  2085
#     PC  2100
#     PC  2099
#     PC  2120
#     PC  2121
#     PC  2122
#     PC  2073
#     PC  2072
#     PC  2071
#     PC  2086
#     PC  2087
#     PC  2092
#     PC  2093
#     PC  2096
#     PC  2076
#     PC  2077
#     PC  2126
#     PC  2125
#     PC  2119
#     PC  2118
#     PC  2117
#     PC  2114
#     PC  2112
#     PC  2113
#     PC  2109
#     PC  2070
#     PC  2069
#     PC  2094
#     PC  2095
#     PC  2079
#     PC  2154
#     PC  2153
#     PC  2151
#     PC  2150
#     PC  2116
#     PC  2115
#     PC  2111
#     PC  2066
#     PC  2110
#     PC  2067
#     PC  2068
#     PC  2155
#     PC  2768
#     PC  2147
#     PC  2146
#     PC  2152
#     PC  2145
#     PC  2160
#     PC  2142
#     PC  2128
#     PC  2127
#     PC  2064
#     PC  2065
#     PC  2063
#     PC  2763
#     PC  2148
#     PC  2164
#     PC  2161
#     PC  2162
#     PC  2144
#     PC  2141
#     PC  2140
#     PC  2138
#     PC  2060
#     PC  2062
#     PC  2761
#     PC  2767
#     PC  2176
#     PC  2165
#     PC  2163
#     PC  2197
#     PC  2199
#     PC  2143
#     PC  2190
#     PC  2135
#     PC  2137
#     PC  2061
#     PC  2089
#     PC  2090
#     PC  2770
#     PC  2171
#     PC  2177
#     PC  2166
#     PC  2198
#     PC  2200
#     PC  2196
#     PC  2195
#     PC  2136
#     PC  2134
#     PC  2046
#     PC  2088
#     PC  2760
#     PC  2747
#     PC  2170
#     PC  2168
#     PC  2214
#     PC  2212
#     PC  2211
#     PC  2210
#     PC  2209
#     PC  2208
#     PC  2192
#     PC  2191
#     PC  2133
#     PC  2132
#     PC  2047
#     PC  2045
#     PC  2750
#     PC  2565
#     PC  2167
#     PC  2172
#     PC  2213
#     PC  2234
#     PC  2223
#     PC  2222
#     PC  2220
#     PC  2207
#     PC  2206
#     PC  2194
#     PC  2193
#     PC  2131
#     PC  2130
#     PC  2040
#     PC  2566
#     PC  2564
#     PC  2232
#     PC  2226
#     PC  2221
#     PC  2218
#     PC  2217
#     PC  2216
#     PC  2205
#     PC  2204
#     PC  2203
#     PC  2049
#     PC  2038
#     PC  2039
#     PC  2558
#     PC  2227
#     PC  2224
#     PC  2225
#     PC  2219
#     PC  2020
#     PC  2044
#     PC  2042
#     PC  2048
#     PC  2050
#     PC  2037
#     PC  2041
#     PC  2559
#     PC  2228
#     PC  2229
#     PC  2019
#     PC  2018
#     PC  2015
#     PC  2043
#     PC  2008
#     PC  2007
#     PC  2009
#     PC  2230
#     PC  2036
#     PC  2035
#     PC  2032
#     PC  2017
#     PC  2016
#     PC  2010
#     PC  2000
#     PC  2231
#     PC  2034
#     PC  2031
#     PC  2021
#     PC  2011
#     PC  2024
#     PC  2022
#     PC  2025
#     PC  2027
#     PC  2026
#     PC  2023
#     PC  2028
#     PC  2029
#     PC  2030
# Year: 2011
#     PC  2107
#     PC  2106
#     PC  2103
#     PC  2104
#     PC  2102
#     PC  2105
#     PC  2101
#     PC  2084
#     PC  2097
#     PC  2074
#     PC  2075
#     PC  2085
#     PC  2100
#     PC  2099
#     PC  2120
#     PC  2121
#     PC  2122
#     PC  2073
#     PC  2072
#     PC  2071
#     PC  2086
#     PC  2087
#     PC  2092
#     PC  2093
#     PC  2096
#     PC  2076
#     PC  2077
#     PC  2126
#     PC  2125
#     PC  2119
#     PC  2118
#     PC  2117
#     PC  2114
#     PC  2112
#     PC  2113
#     PC  2109
#     PC  2070
#     PC  2069
#     PC  2094
#     PC  2095
#     PC  2079
#     PC  2154
#     PC  2153
#     PC  2151
#     PC  2150
#     PC  2116
#     PC  2115
#     PC  2111
#     PC  2066
#     PC  2110
#     PC  2067
#     PC  2068
#     PC  2155
#     PC  2768
#     PC  2147
#     PC  2146
#     PC  2152
#     PC  2145
#     PC  2160
#     PC  2142
#     PC  2128
#     PC  2127
#     PC  2064
#     PC  2065
#     PC  2063
#     PC  2769
#     PC  2763
#     PC  2148
#     PC  2164
#     PC  2161
#     PC  2162
#     PC  2144
#     PC  2141
#     PC  2140
#     PC  2138
#     PC  2060
#     PC  2062
#     PC  2761
#     PC  2767
#     PC  2176
#     PC  2165
#     PC  2163
#     PC  2197
#     PC  2199
#     PC  2143
#     PC  2190
#     PC  2135
#     PC  2137
#     PC  2139
#     PC  2061
#     PC  2089
#     PC  2090
#     PC  2770
#     PC  2171
#     PC  2177
#     PC  2166
#     PC  2198
#     PC  2200
#     PC  2196
#     PC  2195
#     PC  2136
#     PC  2134
#     PC  2046
#     PC  2088
#     PC  2760
#     PC  2747
#     PC  2174
#     PC  2170
#     PC  2168
#     PC  2214
#     PC  2212
#     PC  2211
#     PC  2210
#     PC  2209
#     PC  2208
#     PC  2192
#     PC  2191
#     PC  2133
#     PC  2132
#     PC  2047
#     PC  2045
#     PC  2750
#     PC  2565
#     PC  2167
#     PC  2172
#     PC  2213
#     PC  2234
#     PC  2223
#     PC  2222
#     PC  2220
#     PC  2207
#     PC  2206
#     PC  2194
#     PC  2193
#     PC  2131
#     PC  2130
#     PC  2040
#     PC  2566
#     PC  2564
#     PC  2232
#     PC  2226
#     PC  2221
#     PC  2218
#     PC  2217
#     PC  2216
#     PC  2205
#     PC  2204
#     PC  2203
#     PC  2049
#     PC  2038
#     PC  2039
#     PC  2558
#     PC  2227
#     PC  2224
#     PC  2225
#     PC  2219
#     PC  2020
#     PC  2044
#     PC  2042
#     PC  2048
#     PC  2050
#     PC  2037
#     PC  2041
#     PC  2559
#     PC  2228
#     PC  2229
#     PC  2019
#     PC  2018
#     PC  2015
#     PC  2043
#     PC  2008
#     PC  2006
#     PC  2007
#     PC  2009
#     PC  2230
#     PC  2036
#     PC  2035
#     PC  2032
#     PC  2017
#     PC  2016
#     PC  2010
#     PC  2000
#     PC  2231
#     PC  2034
#     PC  2031
#     PC  2052
#     PC  2021
#     PC  2011
#     PC  2024
#     PC  2022
#     PC  2025
#     PC  2027
#     PC  2026
#     PC  2023
#     PC  2028
#     PC  2029
#     PC  2030
# Year: 2016
# pc 2107
# pc 2106
# pc 2103
# pc 2104
# pc 2102
# pc 2105
# pc 2101
# pc 2084
# pc 2097
# pc 2074
# pc 2075
# pc 2085
# pc 2100
# pc 2099
# pc 2120
# pc 2121
# pc 2122
# pc 2073
# pc 2072
# pc 2071
# pc 2086
# pc 2087
# pc 2092
# pc 2093
# pc 2096
# pc 2076
# pc 2077
# pc 2126
# pc 2125
# pc 2119
# pc 2118
# pc 2117
# pc 2114
# pc 2112
# pc 2113
# pc 2109
# pc 2070
# pc 2069
# pc 2094
# pc 2095
# pc 2079
# pc 2154
# pc 2153
# pc 2151
# pc 2150
# pc 2116
# pc 2115
# pc 2111
# pc 2066
# pc 2110
# pc 2067
# pc 2068
# pc 2155
# pc 2768
# pc 2147
# pc 2146
# pc 2152
# pc 2145
# pc 2160
# pc 2142
# pc 2128
# pc 2127
# pc 2064
# pc 2065
# pc 2063
# pc 2769
# pc 2763
# pc 2148
# pc 2164
# pc 2161
# pc 2162
# pc 2144
# pc 2141
# pc 2140
# pc 2138
# pc 2060
# pc 2062
# pc 2761
# pc 2767
# pc 2176
1168, 1055, 1680, 1247, 1288, 1136, 1173, 1258, 987, 1134, 1295, 1508, 2150, 1732, 1256, 1293, 1394, 2472, 1442, 2191, 1578, 1303, 1171, 1366, 1370, 945, 1394, 1313, 1572, 1911, 1385, 994, 1525, 1874, 1633, 1266, 1272, 1257, 1411, 1405, 1540, 1688, 2086, 2597, 1514, 1746, 1510, 2172, 1259, 1481, 1684, 1740, 1803, 1950, 1418, 2543, 657, 1372, 1541, 1626, 1197, 2053, 2292, 1459, 1750, 1099, 2184, 1524, 1234, 1432, 1138, 1184, 1447, 1796, 1422, 1605, 1885, 1857, 556, 2114, 1523, 2049, 1785, 2181, 2276, 1910, 2566, 2287, 1906, 2422, 0, 0], [2250, 2066, 2001, 1476, 2160, 2202, 1926, 2467, 2274, 2531, 2542, 2228, 2214, 1805, 2291, 2048, 1645, 3010, 2313, 2532, 2511, 2287, 3384, 2382, 2328, 2469, 1807, 2443, 2675, 2693, 1834, 1574, 1783, 1809, 1917, 1453, 2628, 2846, 2620, 2449, 2268, 2219, 2158, 1709, 1696, 1553, 1620, 1999, 2344, 2739, 1909, 2735, 2569, 2400, 1617, 1724, 1639, 1712, 1237, 1326, 1536, 2005, 2183, 2416, 3344, 2649, 2042, 1498, 1296, 1155, 1168, 1240, 1480, 1723, 1835, 2316, 2361, 1883, 1743, 1567, 1077, 844, 1225, 1203, 1323, 1190, 1883, 2110, 0, 2415, 2349, 2367, 1159, 2093, 1411, 1080, 1464, 1178, 1220, 1036, 1724, 1398, 2098, 2522, 1365, 1603, 2280, 1378, 1255, 1851, 1580, 1536, 1395, 1458, 1564, 1192, 1440, 1597, 1846, 2353, 2164, 1446, 1518, 1757, 2685, 1733, 2400, 1919, 1591, 1422, 1602, 1793, 1239, 1681, 1632, 1940, 2273, 1571, 1216, 1853, 2165, 1946, 1560, 1612, 1540, 1763, 1812, 1811, 1968, 2337, 2873, 1693, 2051, 1768, 2615, 1532, 1955, 2092, 2070, 2179, 1782, 1752, 2672, 785, 1653, 1856, 2028, 1500, 2375, 2482, 1223, 0, 1230, 2280, 1906, 1639, 1736, 1273, 1623, 1821, 2150, 1943, 1898, 2277, 2226, 72, 2399, 1861, 2450, 2157, 2529, 2628, 2325, 2892, 2478, 2270, 2815, 0, 0]]

# %%
for i in range(3):
    while(len(database[i]) <= 198):
        database[i].append(0)
    print(len(database[i]))
db = np.zeros((199,3), np.int32)
db[:,0] = database[0]
db[:, 1] = database[1]
db[:, 2] = database[2]
# Out:
# 199
# 199
# 199

# %%
print(db[0])
df = pd.DataFrame(db)
df.to_csv("sydney_income.csv")
# Out:
# [1562 1887 2250]

# %% [markdown]
# # Melbourne

# %%
# define all postal codes 
input_file = pd.read_csv('melbourne_postal_codes.csv', header=None)
postalcode = input_file.as_matrix()
print(postalcode.shape)
# define years 
years = ["2006", "2011", "2016"]
database = []
# Out:
# (894, 1)
